# %%
import yfinance as yf
import pandas as pd
import sqlite3
from datetime import datetime
import pandas  as pd
import os 

# ----------------------------
# CONFIG
# ----------------------------
list_of_file = os.listdir("./equities/")
list_of_file
DB_NAME = "market_data.db"
TABLE_NAME = "stock_prices"

START_DATE = "2000-01-01"
END_DATE = datetime.today().strftime("%Y-%m-%d")


# ----------------------------
# SQLITE SETUP
# ----------------------------
conn = sqlite3.connect(DB_NAME)
cursor = conn.cursor()

cursor.execute(f"""
CREATE TABLE IF NOT EXISTS {TABLE_NAME} (
    date TEXT NOT NULL,
    ticker TEXT NOT NULL,
    open REAL,
    high REAL,
    low REAL,
    close REAL,
    volume INTEGER,
    PRIMARY KEY (date, ticker)
)
""")

# Performance tuning (safe)
cursor.execute("PRAGMA journal_mode=WAL;")
cursor.execute("PRAGMA synchronous=NORMAL;")

conn.commit()

# ----------------------------
# DOWNLOAD DATA
# ----------------------------
for i in list_of_file:
    print("⏳ Downloading data from NAS...", i)
    
    df = pd.read_csv("./equities/" + i)
    
    if df.empty:
        continue
    if df.shape[0] < 3:
        continue
    
    # ----------------------------
    # NORMALIZE DATA
    # ----------------------------
    # Convert multi-index columns -> rows
    df.columns = ['Date', 'Close', 'High', 'Low', 'Open', 'Volume']
    df['Ticker'] = i.split(".")[0]
    df.drop(df.index[:2], inplace=True)
    df = df[['Ticker','Date', 'Close', 'High', 'Low', 'Open', 'Volume']]
        
    # Drop rows with no volume (market holidays, bad symbols)
    df = df.dropna(subset=["Volume"])
    
    print(f"🚀 Prepared {len(df):,} rows for insertion")
    
    # ----------------------------
    # INSERT INTO SQLITE
    # ----------------------------
    insert_query = f"""
    INSERT OR IGNORE INTO {TABLE_NAME}
    (date, ticker, open, high, low, close, volume)
    VALUES (?, ?, ?, ?, ?, ?, ?)
    """
    
    cursor.executemany(
        insert_query,
        df[["Date", "Ticker", "Open", "High", "Low", "Close", "Volume"]].values.tolist()
    )
    
    conn.commit()
    
    
    print("✅ Data successfully stored in SQLite", i)
conn.close()
# Out:
# ⏳ Downloading data from NAS... CSCO.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite CSCO.csv
# ⏳ Downloading data from NAS... UAL.csv
# 🚀 Prepared 5,040 rows for insertion
# ✅ Data successfully stored in SQLite UAL.csv
# ⏳ Downloading data from NAS... TROW.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite TROW.csv
# ⏳ Downloading data from NAS... ISRG.csv
# 🚀 Prepared 6,456 rows for insertion
# ✅ Data successfully stored in SQLite ISRG.csv
# ⏳ Downloading data from NAS... TPR.csv
# 🚀 Prepared 6,378 rows for insertion
# ✅ Data successfully stored in SQLite TPR.csv
# ⏳ Downloading data from NAS... DVN.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite DVN.csv
# ⏳ Downloading data from NAS... CE.csv
# 🚀 Prepared 5,302 rows for insertion
# ✅ Data successfully stored in SQLite CE.csv
# ⏳ Downloading data from NAS... VRTX.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite VRTX.csv
# ⏳ Downloading data from NAS... GILD.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite GILD.csv
# ⏳ Downloading data from NAS... EQIX.csv
# 🚀 Prepared 6,417 rows for insertion
# ✅ Data successfully stored in SQLite EQIX.csv
# ⏳ Downloading data from NAS... TER.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite TER.csv
# ⏳ Downloading data from NAS... MDT.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite MDT.csv
# ⏳ Downloading data from NAS... V.csv
# 🚀 Prepared 4,508 rows for insertion
# ✅ Data successfully stored in SQLite V.csv
# ⏳ Downloading data from NAS... QRVO.csv
# 🚀 Prepared 2,798 rows for insertion
# ✅ Data successfully stored in SQLite QRVO.csv
# ⏳ Downloading data from NAS... A.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite A.csv
# ⏳ Downloading data from NAS... MO.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite MO.csv
# ⏳ Downloading data from NAS... ENPH.csv
# 🚀 Prepared 3,491 rows for insertion
# ✅ Data successfully stored in SQLite ENPH.csv
# ⏳ Downloading data from NAS... CDNS.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite CDNS.csv
# ⏳ Downloading data from NAS... CHTR.csv
# 🚀 Prepared 4,055 rows for insertion
# ✅ Data successfully stored in SQLite CHTR.csv
# ⏳ Downloading data from NAS... EIX.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite EIX.csv
# ⏳ Downloading data from NAS... KDP.csv
# 🚀 Prepared 4,474 rows for insertion
# ✅ Data successfully stored in SQLite KDP.csv
# ⏳ Downloading data from NAS... BBY.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite BBY.csv
# ⏳ Downloading data from NAS... HCA.csv
# 🚀 Prepared 3,758 rows for insertion
# ✅ Data successfully stored in SQLite HCA.csv
# ⏳ Downloading data from NAS... DTE.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite DTE.csv
# ⏳ Downloading data from NAS... T.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite T.csv
# ⏳ Downloading data from NAS... MGM.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite MGM.csv
# ⏳ Downloading data from NAS... HUM.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite HUM.csv
# ⏳ Downloading data from NAS... CFG.csv
# 🚀 Prepared 2,867 rows for insertion
# ✅ Data successfully stored in SQLite CFG.csv
# ⏳ Downloading data from NAS... MSI.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite MSI.csv
# ⏳ Downloading data from NAS... LH.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite LH.csv
# ⏳ Downloading data from NAS... PKI.csv
# ⏳ Downloading data from NAS... LNT.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite LNT.csv
# ⏳ Downloading data from NAS... BAC.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite BAC.csv
# ⏳ Downloading data from NAS... PSX.csv
# 🚀 Prepared 3,483 rows for insertion
# ✅ Data successfully stored in SQLite PSX.csv
# ⏳ Downloading data from NAS... GPN.csv
# 🚀 Prepared 6,310 rows for insertion
# ✅ Data successfully stored in SQLite GPN.csv
# ⏳ Downloading data from NAS... PPG.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite PPG.csv
# ⏳ Downloading data from NAS... TECH.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite TECH.csv
# ⏳ Downloading data from NAS... IRM.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite IRM.csv
# ⏳ Downloading data from NAS... IQV.csv
# 🚀 Prepared 3,214 rows for insertion
# ✅ Data successfully stored in SQLite IQV.csv
# ⏳ Downloading data from NAS... HAL.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite HAL.csv
# ⏳ Downloading data from NAS... STZ.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite STZ.csv
# ⏳ Downloading data from NAS... ADI.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite ADI.csv
# ⏳ Downloading data from NAS... ADBE.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite ADBE.csv
# ⏳ Downloading data from NAS... CPRT.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite CPRT.csv
# ⏳ Downloading data from NAS... TFX.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite TFX.csv
# ⏳ Downloading data from NAS... ULTA.csv
# 🚀 Prepared 4,607 rows for insertion
# ✅ Data successfully stored in SQLite ULTA.csv
# ⏳ Downloading data from NAS... ARE.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite ARE.csv
# ⏳ Downloading data from NAS... SYK.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite SYK.csv
# ⏳ Downloading data from NAS... CB.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite CB.csv
# ⏳ Downloading data from NAS... GNRC.csv
# 🚀 Prepared 4,029 rows for insertion
# ✅ Data successfully stored in SQLite GNRC.csv
# ⏳ Downloading data from NAS... PEP.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite PEP.csv
# ⏳ Downloading data from NAS... PEG.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite PEG.csv
# ⏳ Downloading data from NAS... NOW.csv
# 🚀 Prepared 3,428 rows for insertion
# ✅ Data successfully stored in SQLite NOW.csv
# ⏳ Downloading data from NAS... LLY.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite LLY.csv
# ⏳ Downloading data from NAS... COST.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite COST.csv
# ⏳ Downloading data from NAS... LOW.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite LOW.csv
# ⏳ Downloading data from NAS... BKNG.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite BKNG.csv
# ⏳ Downloading data from NAS... ZBRA.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite ZBRA.csv
# ⏳ Downloading data from NAS... FMC.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite FMC.csv
# ⏳ Downloading data from NAS... DLR.csv
# 🚀 Prepared 5,359 rows for insertion
# ✅ Data successfully stored in SQLite DLR.csv
# ⏳ Downloading data from NAS... FAST.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite FAST.csv
# ⏳ Downloading data from NAS... TJX.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite TJX.csv
# ⏳ Downloading data from NAS... SNA.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite SNA.csv
# ⏳ Downloading data from NAS... BR.csv
# 🚀 Prepared 4,758 rows for insertion
# ✅ Data successfully stored in SQLite BR.csv
# ⏳ Downloading data from NAS... MRK.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite MRK.csv
# ⏳ Downloading data from NAS... BXP.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite BXP.csv
# ⏳ Downloading data from NAS... KHC.csv
# 🚀 Prepared 2,672 rows for insertion
# ✅ Data successfully stored in SQLite KHC.csv
# ⏳ Downloading data from NAS... UNP.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite UNP.csv
# ⏳ Downloading data from NAS... ALLE.csv
# 🚀 Prepared 3,080 rows for insertion
# ✅ Data successfully stored in SQLite ALLE.csv
# ⏳ Downloading data from NAS... ABBV.csv
# 🚀 Prepared 3,302 rows for insertion
# ✅ Data successfully stored in SQLite ABBV.csv
# ⏳ Downloading data from NAS... ORCL.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite ORCL.csv
# ⏳ Downloading data from NAS... EBAY.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite EBAY.csv
# ⏳ Downloading data from NAS... IR.csv
# 🚀 Prepared 2,204 rows for insertion
# ✅ Data successfully stored in SQLite IR.csv
# ⏳ Downloading data from NAS... INTU.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite INTU.csv
# ⏳ Downloading data from NAS... CMA.csv
# 🚀 Prepared 6,559 rows for insertion
# ✅ Data successfully stored in SQLite CMA.csv
# ⏳ Downloading data from NAS... PG.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite PG.csv
# ⏳ Downloading data from NAS... CAT.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite CAT.csv
# ⏳ Downloading data from NAS... ODFL.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite ODFL.csv
# ⏳ Downloading data from NAS... MCD.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite MCD.csv
# ⏳ Downloading data from NAS... MNST.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite MNST.csv
# ⏳ Downloading data from NAS... AMZN.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite AMZN.csv
# ⏳ Downloading data from NAS... PNR.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite PNR.csv
# ⏳ Downloading data from NAS... GLW.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite GLW.csv
# ⏳ Downloading data from NAS... BDX.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite BDX.csv
# ⏳ Downloading data from NAS... PWR.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite PWR.csv
# ⏳ Downloading data from NAS... APTV.csv
# 🚀 Prepared 3,582 rows for insertion
# ✅ Data successfully stored in SQLite APTV.csv
# ⏳ Downloading data from NAS... DXCM.csv
# 🚀 Prepared 5,245 rows for insertion
# ✅ Data successfully stored in SQLite DXCM.csv
# ⏳ Downloading data from NAS... WELL.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite WELL.csv
# ⏳ Downloading data from NAS... HOLX.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite HOLX.csv
# ⏳ Downloading data from NAS... GM.csv
# 🚀 Prepared 3,834 rows for insertion
# ✅ Data successfully stored in SQLite GM.csv
# ⏳ Downloading data from NAS... TXN.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite TXN.csv
# ⏳ Downloading data from NAS... VRSK.csv
# 🚀 Prepared 4,116 rows for insertion
# ✅ Data successfully stored in SQLite VRSK.csv
# ⏳ Downloading data from NAS... OXY.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite OXY.csv
# ⏳ Downloading data from NAS... MOS.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite MOS.csv
# ⏳ Downloading data from NAS... FTNT.csv
# 🚀 Prepared 4,086 rows for insertion
# ✅ Data successfully stored in SQLite FTNT.csv
# ⏳ Downloading data from NAS... ED.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite ED.csv
# ⏳ Downloading data from NAS... ES.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite ES.csv
# ⏳ Downloading data from NAS... IP.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite IP.csv
# ⏳ Downloading data from NAS... EXPE.csv
# 🚀 Prepared 5,177 rows for insertion
# ✅ Data successfully stored in SQLite EXPE.csv
# ⏳ Downloading data from NAS... KO.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite KO.csv
# ⏳ Downloading data from NAS... PCAR.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite PCAR.csv
# ⏳ Downloading data from NAS... NEE.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite NEE.csv
# ⏳ Downloading data from NAS... UPS.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite UPS.csv
# ⏳ Downloading data from NAS... ELV.csv
# 🚀 Prepared 6,114 rows for insertion
# ✅ Data successfully stored in SQLite ELV.csv
# ⏳ Downloading data from NAS... EMR.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite EMR.csv
# ⏳ Downloading data from NAS... MSFT.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite MSFT.csv
# ⏳ Downloading data from NAS... ANSS.csv
# ⏳ Downloading data from NAS... CTAS.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite CTAS.csv
# ⏳ Downloading data from NAS... BIO.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite BIO.csv
# ⏳ Downloading data from NAS... UDR.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite UDR.csv
# ⏳ Downloading data from NAS... CTLT.csv
# ⏳ Downloading data from NAS... WEC.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite WEC.csv
# ⏳ Downloading data from NAS... AME.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite AME.csv
# ⏳ Downloading data from NAS... IT.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite IT.csv
# ⏳ Downloading data from NAS... DD.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite DD.csv
# ⏳ Downloading data from NAS... ACN.csv
# 🚀 Prepared 6,182 rows for insertion
# ✅ Data successfully stored in SQLite ACN.csv
# ⏳ Downloading data from NAS... EW.csv
# 🚀 Prepared 6,513 rows for insertion
# ✅ Data successfully stored in SQLite EW.csv
# ⏳ Downloading data from NAS... CMG.csv
# 🚀 Prepared 5,047 rows for insertion
# ✅ Data successfully stored in SQLite CMG.csv
# ⏳ Downloading data from NAS... COO.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite COO.csv
# ⏳ Downloading data from NAS... SHW.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite SHW.csv
# ⏳ Downloading data from NAS... HPQ.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite HPQ.csv
# ⏳ Downloading data from NAS... AMAT.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite AMAT.csv
# ⏳ Downloading data from NAS... MLM.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite MLM.csv
# ⏳ Downloading data from NAS... AVY.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite AVY.csv
# ⏳ Downloading data from NAS... AAP.csv
# 🚀 Prepared 6,093 rows for insertion
# ✅ Data successfully stored in SQLite AAP.csv
# ⏳ Downloading data from NAS... EVRG.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite EVRG.csv
# ⏳ Downloading data from NAS... EA.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite EA.csv
# ⏳ Downloading data from NAS... DE.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite DE.csv
# ⏳ Downloading data from NAS... AMD.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite AMD.csv
# ⏳ Downloading data from NAS... NDAQ.csv
# 🚀 Prepared 5,947 rows for insertion
# ✅ Data successfully stored in SQLite NDAQ.csv
# ⏳ Downloading data from NAS... WHR.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite WHR.csv
# ⏳ Downloading data from NAS... RTX.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite RTX.csv
# ⏳ Downloading data from NAS... NXPI.csv
# 🚀 Prepared 3,907 rows for insertion
# ✅ Data successfully stored in SQLite NXPI.csv
# ⏳ Downloading data from NAS... PNC.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite PNC.csv
# ⏳ Downloading data from NAS... BIIB.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite BIIB.csv
# ⏳ Downloading data from NAS... NVDA.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite NVDA.csv
# ⏳ Downloading data from NAS... ROP.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite ROP.csv
# ⏳ Downloading data from NAS... IDXX.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite IDXX.csv
# ⏳ Downloading data from NAS... EXC.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite EXC.csv
# ⏳ Downloading data from NAS... HD.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite HD.csv
# ⏳ Downloading data from NAS... VLO.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite VLO.csv
# ⏳ Downloading data from NAS... AON.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite AON.csv
# ⏳ Downloading data from NAS... ZTS.csv
# 🚀 Prepared 3,281 rows for insertion
# ✅ Data successfully stored in SQLite ZTS.csv
# ⏳ Downloading data from NAS... FDX.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite FDX.csv
# ⏳ Downloading data from NAS... DG.csv
# 🚀 Prepared 4,089 rows for insertion
# ✅ Data successfully stored in SQLite DG.csv
# ⏳ Downloading data from NAS... TYL.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite TYL.csv
# ⏳ Downloading data from NAS... HIG.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite HIG.csv
# ⏳ Downloading data from NAS... SCHW.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite SCHW.csv
# ⏳ Downloading data from NAS... HSIC.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite HSIC.csv
# ⏳ Downloading data from NAS... AZO.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite AZO.csv
# ⏳ Downloading data from NAS... AXP.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite AXP.csv
# ⏳ Downloading data from NAS... HPE.csv
# 🚀 Prepared 2,598 rows for insertion
# ✅ Data successfully stored in SQLite HPE.csv
# ⏳ Downloading data from NAS... DFS.csv
# ⏳ Downloading data from NAS... SEE.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite SEE.csv
# ⏳ Downloading data from NAS... SO.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite SO.csv
# ⏳ Downloading data from NAS... FRT.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite FRT.csv
# ⏳ Downloading data from NAS... CME.csv
# 🚀 Prepared 5,836 rows for insertion
# ✅ Data successfully stored in SQLite CME.csv
# ⏳ Downloading data from NAS... XOM.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite XOM.csv
# ⏳ Downloading data from NAS... AMP.csv
# 🚀 Prepared 5,138 rows for insertion
# ✅ Data successfully stored in SQLite AMP.csv
# ⏳ Downloading data from NAS... CMCSA.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite CMCSA.csv
# ⏳ Downloading data from NAS... ICE.csv
# 🚀 Prepared 5,094 rows for insertion
# ✅ Data successfully stored in SQLite ICE.csv
# ⏳ Downloading data from NAS... BEN.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite BEN.csv
# ⏳ Downloading data from NAS... UHS.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite UHS.csv
# ⏳ Downloading data from NAS... EMN.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite EMN.csv
# ⏳ Downloading data from NAS... SBAC.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite SBAC.csv
# ⏳ Downloading data from NAS... ROK.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite ROK.csv
# ⏳ Downloading data from NAS... NRG.csv
# 🚀 Prepared 5,588 rows for insertion
# ✅ Data successfully stored in SQLite NRG.csv
# ⏳ Downloading data from NAS... NSC.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite NSC.csv
# ⏳ Downloading data from NAS... NKE.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite NKE.csv
# ⏳ Downloading data from NAS... FIS.csv
# 🚀 Prepared 6,202 rows for insertion
# ✅ Data successfully stored in SQLite FIS.csv
# ⏳ Downloading data from NAS... VTR.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite VTR.csv
# ⏳ Downloading data from NAS... RF.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite RF.csv
# ⏳ Downloading data from NAS... ETSY.csv
# 🚀 Prepared 2,727 rows for insertion
# ✅ Data successfully stored in SQLite ETSY.csv
# ⏳ Downloading data from NAS... MAR.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite MAR.csv
# ⏳ Downloading data from NAS... XYL.csv
# 🚀 Prepared 3,607 rows for insertion
# ✅ Data successfully stored in SQLite XYL.csv
# ⏳ Downloading data from NAS... MTD.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite MTD.csv
# ⏳ Downloading data from NAS... KR.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite KR.csv
# ⏳ Downloading data from NAS... PLD.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite PLD.csv
# ⏳ Downloading data from NAS... IBM.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite IBM.csv
# ⏳ Downloading data from NAS... USB.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite USB.csv
# ⏳ Downloading data from NAS... LIN.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite LIN.csv
# ⏳ Downloading data from NAS... ITW.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite ITW.csv
# ⏳ Downloading data from NAS... EOG.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite EOG.csv
# ⏳ Downloading data from NAS... KMB.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite KMB.csv
# ⏳ Downloading data from NAS... PEAK.csv
# ⏳ Downloading data from NAS... SPGI.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite SPGI.csv
# ⏳ Downloading data from NAS... GS.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite GS.csv
# ⏳ Downloading data from NAS... GD.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite GD.csv
# ⏳ Downloading data from NAS... CNP.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite CNP.csv
# ⏳ Downloading data from NAS... PM.csv
# 🚀 Prepared 4,510 rows for insertion
# ✅ Data successfully stored in SQLite PM.csv
# ⏳ Downloading data from NAS... RE.csv
# ⏳ Downloading data from NAS... MCO.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite MCO.csv
# ⏳ Downloading data from NAS... DIS.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite DIS.csv
# ⏳ Downloading data from NAS... GE.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite GE.csv
# ⏳ Downloading data from NAS... HII.csv
# 🚀 Prepared 3,750 rows for insertion
# ✅ Data successfully stored in SQLite HII.csv
# ⏳ Downloading data from NAS... LDOS.csv
# 🚀 Prepared 4,864 rows for insertion
# ✅ Data successfully stored in SQLite LDOS.csv
# ⏳ Downloading data from NAS... ALL.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite ALL.csv
# ⏳ Downloading data from NAS... ETN.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite ETN.csv
# ⏳ Downloading data from NAS... ALGN.csv
# 🚀 Prepared 6,300 rows for insertion
# ✅ Data successfully stored in SQLite ALGN.csv
# ⏳ Downloading data from NAS... NFLX.csv
# 🚀 Prepared 5,973 rows for insertion
# ✅ Data successfully stored in SQLite NFLX.csv
# ⏳ Downloading data from NAS... LEN.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite LEN.csv
# ⏳ Downloading data from NAS... FITB.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite FITB.csv
# ⏳ Downloading data from NAS... GWW.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite GWW.csv
# ⏳ Downloading data from NAS... NTRS.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite NTRS.csv
# ⏳ Downloading data from NAS... FICO.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite FICO.csv
# ⏳ Downloading data from NAS... FE.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite FE.csv
# ⏳ Downloading data from NAS... JPM.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite JPM.csv
# ⏳ Downloading data from NAS... ABT.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite ABT.csv
# ⏳ Downloading data from NAS... TSCO.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite TSCO.csv
# ⏳ Downloading data from NAS... PH.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite PH.csv
# ⏳ Downloading data from NAS... HST.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite HST.csv
# ⏳ Downloading data from NAS... TSLA.csv
# 🚀 Prepared 3,934 rows for insertion
# ✅ Data successfully stored in SQLite TSLA.csv
# ⏳ Downloading data from NAS... MOH.csv
# 🚀 Prepared 5,694 rows for insertion
# ✅ Data successfully stored in SQLite MOH.csv
# ⏳ Downloading data from NAS... COP.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite COP.csv
# ⏳ Downloading data from NAS... DHR.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite DHR.csv
# ⏳ Downloading data from NAS... TXT.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite TXT.csv
# ⏳ Downloading data from NAS... MTB.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite MTB.csv
# ⏳ Downloading data from NAS... AKAM.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite AKAM.csv
# ⏳ Downloading data from NAS... ROL.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite ROL.csv
# ⏳ Downloading data from NAS... RMD.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite RMD.csv
# ⏳ Downloading data from NAS... WRB.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite WRB.csv
# ⏳ Downloading data from NAS... GOOGL.csv
# 🚀 Prepared 5,409 rows for insertion
# ✅ Data successfully stored in SQLite GOOGL.csv
# ⏳ Downloading data from NAS... ANET.csv
# 🚀 Prepared 2,943 rows for insertion
# ✅ Data successfully stored in SQLite ANET.csv
# ⏳ Downloading data from NAS... PAYX.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite PAYX.csv
# ⏳ Downloading data from NAS... DRI.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite DRI.csv
# ⏳ Downloading data from NAS... ILMN.csv
# 🚀 Prepared 6,427 rows for insertion
# ✅ Data successfully stored in SQLite ILMN.csv
# ⏳ Downloading data from NAS... META.csv
# 🚀 Prepared 3,457 rows for insertion
# ✅ Data successfully stored in SQLite META.csv
# ⏳ Downloading data from NAS... AAL.csv
# 🚀 Prepared 5,130 rows for insertion
# ✅ Data successfully stored in SQLite AAL.csv
# ⏳ Downloading data from NAS... MAA.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite MAA.csv
# ⏳ Downloading data from NAS... MMC.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite MMC.csv
# ⏳ Downloading data from NAS... POOL.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite POOL.csv
# ⏳ Downloading data from NAS... CINF.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite CINF.csv
# ⏳ Downloading data from NAS... VMC.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite VMC.csv
# ⏳ Downloading data from NAS... MKTX.csv
# 🚀 Prepared 5,354 rows for insertion
# ✅ Data successfully stored in SQLite MKTX.csv
# ⏳ Downloading data from NAS... SRE.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite SRE.csv
# ⏳ Downloading data from NAS... ORLY.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite ORLY.csv
# ⏳ Downloading data from NAS... RCL.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite RCL.csv
# ⏳ Downloading data from NAS... SNPS.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite SNPS.csv
# ⏳ Downloading data from NAS... GOOG.csv
# 🚀 Prepared 5,409 rows for insertion
# ✅ Data successfully stored in SQLite GOOG.csv
# ⏳ Downloading data from NAS... NDSN.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite NDSN.csv
# ⏳ Downloading data from NAS... YUM.csv
# 🚀 Prepared 6,571 rows for insertion
# ✅ Data successfully stored in SQLite YUM.csv
# ⏳ Downloading data from NAS... .ipynb_checkpoints
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[16], line 51
#      48 for i in list_of_file:
#      49     print("⏳ Downloading data from NAS...", i)
# ---> 51     df = pd.read_csv("./equities/" + i)
#      53     if df.empty:
#      54         continue
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# IsADirectoryError: [Errno 21] Is a directory: './equities/.ipynb_checkpoints'
